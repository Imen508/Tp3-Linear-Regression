# %% [markdown]
#  <img src="isitcom.png" width="90" align="center"> <img src="un.png" width="120" align="right"> <h1><center><span style="color:red">Tp3 </span></center></h1>

# %% [markdown]
# <h1><center><span style="color:red">Réalise par :Imen Ayari </span></center></h1>

# %% [markdown]
# <img src="Lin.jpg" width="1000" align="center">

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# <h3><span style="color:blue"> Example 1 </span></h3>

# %%
# Data loading
df = pd.read_csv('grav.csv')
df.head()
# Out:
#    height  seconds squared
# 0     100            8.967
# 1     120           11.989
# 2     150           15.852
# 3     180           16.991
# 4     200           20.284

# %%
# Selection of the first column of our dataset (height)
X = df.iloc[0:len(df),0]
# Selection of second columns of our dataset (seconds squared)
Y = df.iloc[0:len(df),1]

# %%
axes = plt.axes()
# Draw a grid
axes.grid()  
# X and Y are the variables that we extracted in the previous part
plt.scatter(X,Y) 
plt.show()

# %%
from scipy import stats

# Linregress () returns multiple return variables - We are particularly interested in slope and intercept
slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)
def predict(x):
    return slope * x + intercept
# The fitLine variable will be an array of predicted values from the X array
fitLine = predict(X)
plt.plot(X, fitLine, c='r')

# %%
# Print the value of 'slope'
print (slope)
# Out:
# 0.10280912511759172

# %%
# Print the value of 'intercept'
print (intercept)
# Out:
# -0.6801232361241745

# %% [markdown]
# <h3> <span style="color:blue">Example 2 </span></h3>

# %%
# !pip install pyreadstat

# %%
# Data loading
import pyreadstat

df, metadata = pyreadstat.read_sav("test_scores.sav")
df.head(10)
# Out:
#   school  school_setting  school_type classroom  teaching_method  n_student  \
# 0  ANKYI             1.0          2.0       6OL              0.0       20.0
# 1  ANKYI             1.0          2.0       6OL              0.0       20.0
# 2  ANKYI             1.0          2.0       6OL              0.0       20.0
# 3  ANKYI             1.0          2.0       6OL              0.0       20.0
# 4  ANKYI             1.0          2.0       6OL              0.0       20.0
# 5  ANKYI             1.0          2.0       6OL              0.0       20.0
# 6  ANKYI             1.0          2.0       6OL              0.0       20.0
# 7  ANKYI             1.0          2.0       6OL              0.0       20.0
# 8  ANKYI             1.0          2.0       6OL              0.0       20.0
# 9  ANKYI             1.0          2.0       6OL              0.0       20.0
#
#   student_id  gender  lunch  pretest  posttest
# 0      2FHT3     1.0    2.0     62.0      72.0
# ...

# %%
# Shape of our dataset
df.shape
# Info our dataset
df.info()
# Describe our dataset
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2133 entries, 0 to 2132
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   school           2133 non-null   object
#  1   school_setting   2133 non-null   float64
#  2   school_type      2133 non-null   float64
#  3   classroom        2133 non-null   object
#  4   teaching_method  2133 non-null   float64
#  5   n_student        2133 non-null   float64
#  6   student_id       2133 non-null   object
#  7   gender           2133 non-null   float64
#  8   lunch            2133 non-null   float64
#  9   pretest          2133 non-null   float64
#  10  posttest         2133 non-null   float64
# dtypes: float64(8), object(3)
# memory usage: 183.4+ KB
#        school_setting  school_type  teaching_method    n_student       gender  \
# count     2133.000000  2133.000000      2133.000000  2133.000000  2133.000000
# ...

# %%
# Using pairplot we'll visualize the data for correlation
sns.pairplot(df, x_vars=['school','school_setting','school_type','classroom','teaching_method','n_student','student_id','gender', 'lunch','pretest'], 
             y_vars='posttest', size=4, aspect=1, kind='scatter')
plt.show()
# Out:
# C:\Users\Hp\Anaconda3\lib\site-packages\seaborn\axisgrid.py:1912: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# Visualizing the data using heatmap
sns.heatmap(df.corr(), cmap="YlGnBu", annot = True)
plt.show()

# %%
# Creating X and y
X = df['pretest']
y = df['posttest']
plt.scatter(X,y)
plt.xlabel("pretest")
plt.ylabel("posttest")
# Out:
# Text(0, 0.5, 'posttest')

# %%
# Splitting the varaibles as training and testing
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.7, 
                                                    test_size = 0.3, random_state = 100)

# %%
# Take a look at the train dataset
X_train
y_train
# Out:
# 1455    81.0
# 299     67.0
# 1912    49.0
# 863     92.0
# 298     64.0
#         ...
# 350     57.0
# 1930    53.0
# 79      79.0
# 1859    47.0
# 1544    89.0
# Name: posttest, Length: 1493, dtype: float64

# %%
# Importing Statsmodels.api library from Stamodel package
import statsmodels.api as sm

# Adding a constant to get an intercept
X_train_sm = sm.add_constant(X_train)

# %%
# Fitting the resgression line using 'OLS'
lr = sm.OLS(y_train, X_train_sm).fit()
# Printing the parameters
lr.params
# Out:
# const      13.374988
# pretest     0.978308
# dtype: float64

# %%
# Performing a summary to list out all the different parameters of the regression line fitted
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               posttest   R-squared:                       0.905
# Model:                            OLS   Adj. R-squared:                  0.905
# Method:                 Least Squares   F-statistic:                 1.429e+04
# Date:                Fri, 04 Dec 2020   Prob (F-statistic):               0.00
# Time:                        20:21:51   Log-Likelihood:                -4291.4
# No. Observations:                1493   AIC:                             8587.
# Df Residuals:                    1491   BIC:                             8597.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         13.3750      0.465     28.776      0.000      12.463      14.287
# ...

# %%
# Visualizing the regression line
plt.scatter(X_train, y_train)
plt.plot(X_train, 13.3750 + 0.9783*X_train, 'r')
plt.show()

# %%
# Predicting y_value using traingn data of X
y_train_pred = lr.predict(X_train_sm)
# Creating residuals from the y_train data and predicted y_data
res = (y_train - y_train_pred)

# %%
# Plotting the histogram using the residual values
fig = plt.figure()
sns.distplot(res, bins = 15)
plt.title('Error Terms', fontsize = 15)
plt.xlabel('y_train - y_train_pred', fontsize = 15)
plt.show()
# Out:
# C:\Users\Hp\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Looking for any patterns in the residuals
plt.scatter(X_train,res)
plt.show()

# %%
# Adding a constant to X_test
X_test_sm = sm.add_constant(X_test)
# Predicting the y values corresponding to X_test_sm
y_test_pred = lr.predict(X_test_sm)
# Printing the first 15 predicted values
y_test_pred
# Out:
# 686     58.377169
# 1836    58.377169
# 1587    88.704726
# 63      78.921643
# 1348    71.095177
#           ...
# 146     76.965027
# 374     51.529011
# 1989    75.986718
# 581     53.485628
# 272     64.247019
# Length: 640, dtype: float64

# %%
# Importing r2_square
from sklearn.metrics import r2_score

# Checking the R-squared value
r_squared = r2_score(y_test, y_test_pred)
r_squared
# Out:
# 0.9009451419275621

# %%
# Visualize the line on the test set
plt.scatter(X_test, y_test)
plt.plot(X_test, y_test_pred, 'r')
plt.show()

# %%
# Splitting the data into train and test
from sklearn.model_selection import train_test_split

X_train_lm, X_test_lm, y_train_lm, y_test_lm = train_test_split(X, y, train_size = 0.7, 
                                                                test_size = 0.3, random_state = 100)

# %%
# Shape of the train set without adding column
X_train_lm.shape
# Adding additional column to the train and test data
X_train_lm = X_train_lm.values.reshape(-1,1)
X_test_lm = X_test_lm.values.reshape(-1,1)
print(X_train_lm.shape)
print(X_test_lm.shape)
# Out:
# (1493, 1)
# (640, 1)

# %%
from sklearn.linear_model import LinearRegression

# Creating an object of Linear Regression
lm = LinearRegression()
# Fit the model using .fit() method
lm.fit(X_train_lm, y_train_lm)
# Out:
# LinearRegression()

# %%
# Intercept value
print("Intercept :",lm.intercept_)
# Slope value
print('Slope :',lm.coef_)
# Out:
# Intercept : 13.374988195767308
# Slope : [0.97830828]

# %%
# Making Predictions of y_value
y_train_pred = lm.predict(X_train_lm)
y_test_pred = lm.predict(X_test_lm)
# Comparing the r2 value of both train and test data
print(r2_score(y_train,y_train_pred))
print(r2_score(y_test,y_test_pred))
# Out:
# 0.9054961340673476
# 0.900945141927562

# %% [markdown]
# <h3><span style="color:blue"> Example 3 </span></h3>

# %%
# Loading the data
boston = pd.read_csv('housing.data.txt' , sep=",")
print("housing's shape : ", boston.shape)
# Print the first 10 rows of the data
boston.head(10)
# Out:
# housing's shape :  (506, 14)
#       CIRM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222.0
# 5  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222.0
# 6  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311.0
# 7  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311.0
# 8  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311.0
# 9  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# ...

# %% [markdown]
# <h3><span style="color:orange"> Data preprocessing </span></h3>

# %% [markdown]
# Après avoir chargé les données, nous pouvons vérifier s'il y a des valeurs manquantes dans les données. Nous comptons le nombre de valeurs manquantes pour chaque fonctionnalité en utilisant isnull().

# %%
boston.isnull().sum()
# Out:
# CIRM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %% [markdown]
# <h3><span style="color:orange"> Data Analysis </span></h3>

# %% [markdown]
# L'analyse exploratoire des données est une étape très importante avant la formation du modèle. Dans cette section, nous utiliserons quelques visualisations pour comprendre la relation de la variable cible avec d'autres fonctionnalités.

# %%
# Plot the distribution of the target variable MEDV
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.distplot(boston['MEDV'], bins=30)
plt.show()
# Out:
# C:\Users\Hp\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# <h4><span style="color:Purple"> Remarque: </span></h4>

# %% [markdown]
# On voit que les valeurs de MEDV sont distribuées normalement avec peu de valeurs aberrantes.

# %% [markdown]
# > Ensuite, nous créons une matrice de corrélation qui mesure les relations linéaires entre les variables. La matrice de corrélation peut être formée en utilisant la fonction de la bibliothèque pandas dataframe. Nous utiliserons la fonction heatmap de la bibliothèque seaborn pour tracer la matrice de corrélation.

# %%
correlation_matrix = boston.corr().round(2)
# annot = True to print the values inside the square
sns.heatmap(data=correlation_matrix, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# > Le coefficient de corrélation va de -1 à 1. Si la valeur est proche de 1, cela signifie qu'il existe une forte corrélation positive entre les deux variables. Lorsqu'il est proche de -1, les variables ont une forte corrélation négative.

# %% [markdown]
# <h4><span style="color:Purple"> Remarque: </span></h4>

# %% [markdown]
#  Pour ajuster un modèle de régression linéaire, nous sélectionnons les entités qui ont une forte corrélation avec notre variable cible MEDV. En regardant la matrice de corrélation, nous pouvons voir que RM a une forte corrélation positive avec MEDV (0,7) alors que LSTAT a une forte corrélation négative avec MEDV (-0,74).

# %% [markdown]
#  Un point important dans la sélection des entités pour un modèle de régression linéaire est de vérifier la multi-colinéarité. Les fonctionnalités RAD, TAX ont une corrélation de 0,91. Ces paires de caractéristiques sont fortement corrélées les unes aux autres. Nous ne devons pas sélectionner ces deux fonctionnalités ensemble pour entraîner le modèle. Il en va de même pour les fonctionnalités DIS et AGE qui ont une corrélation de -0,75.

# %%
plt.figure(figsize=(20, 5))

features = ['LSTAT', 'RM']
target = boston['MEDV']

for i, col in enumerate(features):
    plt.subplot(1, len(features) , i+1)
    x = boston[col]
    y = target
    plt.scatter(x, y, marker='o')
    plt.title(col)
    plt.xlabel(col)
    plt.ylabel('MEDV')

# %% [markdown]
# <h4><span style="color:Purple"> Remarque: </span></h4>

# %% [markdown]
# Les prix augmentent à mesure que la valeur de RM augmente linéairement. Il y a peu de valeurs aberrantes et les données semblent plafonnées à 50.
# Les prix ont tendance à baisser avec une augmentation de LSTAT. Bien qu'il ne semble pas suivre exactement une ligne linéaire.

# %% [markdown]
# <h3> <span style="color:orange">Preparing the data for training the model</span> </h3>

# %% [markdown]
# > Nous concaténons les colonnes LSTAT et RM en utilisant np.c_provided par la bibliothèque numpy.

# %%
X = pd.DataFrame(np.c_[boston['LSTAT'], boston['RM']], columns = ['LSTAT','RM'])
Y = boston['MEDV']

# %% [markdown]
# <h3><span style="color:orange"> Splitting the data into training and testing sets </span></h3>

# %% [markdown]
# Ensuite, nous divisons les données en ensembles d'entraînement et de test. Nous formons le modèle avec 70% des échantillons et testons avec les 30% restants. Nous faisons cela pour évaluer les performances du modèle sur des données invisibles. Pour diviser les données, nous utilisons la fonction train_test_split fournie par la bibliothèque scikit-learn. Nous imprimons enfin les tailles de notre ensemble d'entraînement et de test pour vérifier si le fractionnement s'est produit correctement.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3, random_state=5)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (354, 2)
# (152, 2)
# (354,)
# (152,)

# %% [markdown]
# <h3><span style="color:orange"> Training and testing the model </span></h3>

# %% [markdown]
# Nous utilisons LinearRegression de scikit-learn pour entraîner notre modèle sur les ensembles de formation et de test.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

lin_model = LinearRegression()
lin_model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# <h3><span style="color:orange"> Model evaluation</span> </h3>

# %% [markdown]
# Nous évaluerons notre modèle en utilisant RMSE et R2-score.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Model evaluation for training set
y_train_predict = lin_model.predict(X_train)
rmse = (np.sqrt(mean_squared_error(Y_train, y_train_predict)))
r2 = r2_score(Y_train, y_train_predict)

print("The model performance for training set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")

# Model evaluation for testing set
y_test_predict = lin_model.predict(X_test)
rmse = (np.sqrt(mean_squared_error(Y_test, y_test_predict)))
r2 = r2_score(Y_test, y_test_predict)

print("The model performance for testing set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
# Out:
# The model performance for training set
# --------------------------------------
# RMSE is 5.291267334085863
# R2 score is 0.6493177656003104
#
#
# The model performance for testing set
# --------------------------------------
# RMSE is 6.041044703455955
# R2 score is 0.6162026947666575

# %%
pip install watermark
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %load_ext watermark

# python, ipython, packages, and machine characteristics
# %watermark -v -m -p pandas,numpy,watermark 

# date
print (" ")
# %watermark -u -n -t -z
# Out:
# Python implementation: CPython
# Python version       : 3.8.5
# IPython version      : 7.19.0
#
# pandas   : 1.1.3
# numpy    : 1.19.2
# watermark: 2.1.0
#
# Compiler    : MSC v.1916 64 bit (AMD64)
# OS          : Windows
# Release     : 10
# Machine     : AMD64
# Processor   : Intel64 Family 6 Model 61 Stepping 4, GenuineIntel
# CPU cores   : 4
# Architecture: 64bit
#
#
# Last updated: Sat Dec 05 2020 00:26:21Romance Standard Time
